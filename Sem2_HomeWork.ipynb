# %% [markdown]
# <a href="https://colab.research.google.com/github/Globnsk/PYTHON/blob/main/Sem2_HomeWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Урок 2. Анализ датасета с помощью Pandas**

# %% [markdown]
# ##**Домашняя работа**

# %% [markdown]
# ###**Условие 1: 1 задача**
# #####Скачать файл в уроке
# #####Считать данные с помощью pandas
# #####Вывести на экран первые 5 строк
# #####*Посмотреть* на описание признаков и на их содержание

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/kc_house_data.csv', quotechar='|')
df['floors'] = df['floors'].map(lambda x: x.lstrip('""').rstrip('""'))
df['date'] = df['date'].map(lambda x: x.lstrip('""').rstrip('""'))
df['zipcode'] = df['zipcode'].map(lambda x: x.lstrip('""').rstrip('""'))
df['id'] = df['id'].map(lambda x: x.lstrip('""'))
df['sqft_lot15'] = df['sqft_lot15'].map(lambda x: x.rstrip('""'))
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608  0263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611  0291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot floors  waterfront  view  ...  grade  sqft_above  \
# 0             1180      5650      1           0     0  ...      7        1180
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650      1           0     0  ...      7        1180              0
# 1      7242      2           0     0  ...      7        2170            400
# 2     10000      1           0     0  ...      6         770              0
# 3      5000      1           0     0  ...      7        1050            910
# 4      8080      1           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ###**Условие 2: 2 задача**
# Проведите первичный анализ данных
# Изучите типы данных
# Найдите количество пропущенных ячеек в данных
# Посчитайте основные статистики по всем признакам и поизучайте их
# Пишите выводы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  object
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  object
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  object
# ...

# %%
df.dtypes
# Out:
# id                object
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors            object
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode           object
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15        object
# dtype: object

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#          waterfront          view     condition         grade    sqft_above  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       0.007542      0.234303      3.409430      7.656873   1788.390691
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe(include=['object'])
# Out:
#                 id             date floors zipcode sqft_lot15
# count        21613            21613  21613   21613      21613
# unique       21436              372      6      70       8689
# top     0795000620  20140623T000000      1   98103       5000
# freq             3              142  10680     602        427

# %% [markdown]
# ###**Условие 3: 3 задача**
# #####Ответьте на несколько вопросов

# %% [markdown]
# ####**В каком диапазоне изменяются стоимости недвижимости?**

# %%
df['price'].min(), df['price'].max()
# Out:
# (75000.0, 7700000.0)

# %% [markdown]
# ####**Какую долю в среднем занимают жилая площадь от всей площади по всем домам?**

# %%
#f"{round((df['sqft_living'].mean() * 100 / df['sqft_lot'].mean()), 2)} %"
#ddf = df['sqft_living']/df['sqft_lot']
ddf = df['sqft_living'].mean()/df['sqft_lot'].mean()
ddf*100
# Out:
# 13.76781757959227

# %% [markdown]
# ####**Как много домов с разными этажами в данных?**

# %%
df['floors'].value_counts()
# Out:
# floors
# 1      10680
# 2       8241
# 1.5     1910
# 3        613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %% [markdown]
# ####**Насколько хорошие состояния у домов в данных?**

# %%
df['condition'].value_counts()
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %% [markdown]
# ####**Найдите года, когда построили первый дом, когда построили последний дом в данных?**

# %%
f"Первый дом - {df['yr_built'].min()}"
# Out:
# 'Первый дом - 1900'

# %%
f"Последний дом - {df['yr_built'].max()}"
# Out:
# 'Последний дом - 2015'

# %% [markdown]
# ###**Условие 4: 4 задача**
# Ответьте на несколько вопросов

# %% [markdown]
# ####**Сколько в среднем стоят дома, у которых 2 спальни?**

# %%
df[df['bedrooms'] == 2]['price'].mean()
# Out:
# 401372.681884058

# %% [markdown]
# ####**Какая в среднем общая площадь домов, у которых стоимость больше 600 000?**

# %%
df[df['price'] > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# ####**Как много домов коснулся ремонт?**

# %%
df[df['yr_renovated'] != 0].shape[0]
# Out:
# 914

# %% [markdown]
# ####**Насколько в среднем стоимость домов с оценкой grade выше 10 отличается от стоимости домов с оценкой grade меньше 4?**

# %%
df[df['grade'] > 10]['price'].mean() - df[df['grade'] < 4]['price'].mean()
# Out:
# 1488885.1175298805

# %% [markdown]
# ###**Условие 5: 5 задача**
# Ответьте на несколько вопросов

# %% [markdown]
# ####**Выберите дом клиенту**
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
client_choiсe = df[((df['view'] == 4) | (df['waterfront'] != 0)) & (df['yr_built'] >= 1980) & (df['condition'] == 5)]['price']
client_choiсe.min(), client_choiсe.max()
# Out:
# (1295000.0, 3000000.0)

# %% [markdown]
# ####**Выберите дом клиенту**
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df[(df['sqft_basement'] == 0) & (df['floors'] == 2) & (df['price'] < 150000)]['condition'].mean()
# Out:
# nan
